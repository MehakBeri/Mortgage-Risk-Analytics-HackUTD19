# %% [markdown]
# # DETAILED ANALYSIS

# %% [markdown]
# # Foreclosures Visualizations

# %%
from IPython.display import Image
Image("foreclosures.jpg")

# %% [markdown]
# # Zero Balance Visualization

# %%
from IPython.display import Image
Image("zero_all_features.jpg")

# %% [markdown]
# # Zero Bal with Chosen Features Visualization

# %%
from IPython.display import Image
Image("zero_some_features.jpg")

# %% [markdown]
# # Delinquency Visualizations

# %%
from IPython.display import Image
Image("d_all.jpg")

# %% [markdown]
# # Methodology
#
# ## AIM:
# To find the labels of for the classification task in the Performance dataset.
# The labels we are interested in are:
# - CeroBalance: 01
# - Delinquency : 0,30 days, 60 days, more than 90 days
# - Foreclosure event: boolean
#
# We created a dataset sampling nearly 100K records from the original data, which can be found at Fannie Mae's portal
#
# Foreclosure analysis:Visualizations
# Data: all features:
# Using cross validation 10 fold
#
# ## ASSUMPTIONS:
# - Imabalanced classes
# - Random Sampling
# - Extension of models

# %%
from IPython.display import Image
Image("f1.png")

# %%
from IPython.display import Image
Image("z1.png")

# %%
from IPython.display import Image
Image("d1.png")
