# %% [markdown]
# # Python Visualizations

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

# %% [markdown]
# ### Foreclosure feature selection

# %%
filename = 'foreclosure_data_2.csv'
dataF = pd.read_csv(filename, header=0)

plt.scatter(dataF['orgLTV'], dataF['foreclosed'])

# %%
plt.scatter(dataF['orgDebttoIncomeRatio'], dataF['foreclosed'])

# %%
plt.scatter(dataF['orgUPB'], dataF['foreclosed'])

# %% [markdown]
# ### Delinquency feature selection

# %%
filenameD = 'delinquency_data.csv'
dataD = pd.read_csv(filenameD, header=0)

# %%
plt.scatter(dataD['orgLTV'], dataD['delinquency'])

# %%
plt.scatter(dataD['orgDebttoIncomeRatio'], dataD['delinquency'])

# %%
plt.scatter(dataD['orgUPB'], dataD['delinquency'])

# %% [markdown]
# ### Zero Balance Code - feature selection

# %%
filenameZ = 'zerobal.csv'
dataZ = pd.read_csv(filenameZ, header=0)

# %%
plt.scatter(dataZ['orgLTV'], dataZ['zerobal'])

# %%
plt.scatter(dataZ['orgDebttoIncomeRatio'], dataZ['zerobal'])

# %%
plt.scatter(dataZ['orgUPB'], dataZ['zerobal'])

# %%
#borrowerCreditScoreAtOrigination
plt.scatter(dataZ['borrowerCreditScoreAtOrigination'], dataZ['zerobal'])

# %%
#firstTimeHomeBuyer
plt.scatter(dataZ['firstTimeHomeBuyer'], dataZ['zerobal'])
